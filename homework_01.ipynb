# %%
from gitsource import GithubRepositoryDataReader

reader = GithubRepositoryDataReader(
    repo_owner="DataTalksClub",
    repo_name="llm-zoomcamp",
    commit_id="8c1834d",
    allowed_extensions={"md"},
    filename_filter=lambda path: "/lessons/" in path,
)

files = reader.read()

# %%
print(f"lesson pages are in the dataset == {len(files)}")
# Out:
# lesson pages are in the dataset == 72

# %%
documents = []

for file in files:
    doc = file.parse()
    documents.append(doc)

# %%
from minsearch import Index
def build_index(documents):
    index = Index(
        text_fields=["content"],
        keyword_fields=["filename"]
    )
    index.fit(documents)
    return index

# %%
index_op = build_index(documents)

# %%
search_results = index_op.search(
    "How does the agentic loop keep calling the model until it stops?",
    num_results=5
)
print(f"filename of first result == {search_results[0]["filename"]}")
# Out:
# filename of first result == 01-agentic-rag/lessons/14-agentic-loop.md

# %%
from dotenv import load_dotenv
load_dotenv()
import os
from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI
import anthropic

# %%
documents = load_faq_data()
index = build_index(documents)

openai_client = OpenAI()

anthropic_client = anthropic.Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# Yes, you can still join. If you want a certificate, you need to submit your project while submissions are still open.

# %%
answer = assistant.rag("How do I run Ollama locally?")
print(answer)
# Out:
# To run Ollama locally, install it first from [https://ollama.com/download](https://ollama.com/download), then open a terminal and run:
#
# ```bash
# ollama run llama3
# ```
#
# This will download the model and start it locally. You can test that the local server is running with:
#
# ```bash
# curl http://localhost:11434
# ```
#
# If you’re on Linux, you can install it with:
#
# ```bash
# curl -fsSL https://ollama.com/install.sh | sh
# ```

# %%
answer = assistant.rag("How do I run Olama locally?")
print(answer)
# Out:
# I don't know.
